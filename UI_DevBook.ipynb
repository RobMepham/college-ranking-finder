# %%
import tkinter as tk
import pandas as pd
import os
import webbrowser
from PIL import Image, ImageTk

import model_gen
import pdf_gen
import email_client

def callback(url):
    # Opens A Chrome Tab
    webbrowser.open_new_tab(url)
    
def exit_procedure():
# THIS IS NOT WORKING AT ALL
    root.destroy()

    
def fn_1():
    # SUB FNS
    def b2_fn():
        # SUB FNS
        def b3_fn():
            def b4_fn():
                def email_procedure():
                    def email_button_fn():
                        # DESTROY STATATMENTS
                        try:
                            for widget in info_frame.winfo_children():
                                widget.destroy()

                            info_frame.destroy()
                            bg_info_frame.destroy()
                        
                        except:
                            pass
                        
                        # FUNCTIONALITY
                        df = pd.read_csv('../data/Interim/df_to_email.csv')
                        try:
                            df = df.drop('Unnamed: 0',axis=1)
                        except:
                            pass

                        rpt_name = str(rpt_name_var.get())
                        to_email = str(to_email_var.get())
                        user_name = str(user_name_var.get())
                        
                        w_df = pd.read_csv('../data/Interim/component_weights.csv')
                        try:
                            w_df = df.drop('Unnamed: 0',axis=1)
                        except:
                            pass
                        try:
                            aca_weight = int(w_df['Academic'].iat[0])
                        except:
                            aca_weight = 0
                        try:
                            ath_weight = int(w_df['Athletic'].iat[0])
                        except:
                            ath_weight = 0
                        try:
                            exc_weight = int(w_df['Exclusivity'].iat[0])
                        except:
                            exc_weight = 0
                        try:
                            soc_weight = int(w_df['Social'].iat[0])
                        except:
                            soc_weight = 0
                        try:
                            afd_weight = int(w_df['Affordability'].iat[0])
                        except:
                            afd_weight = 0
                            
                        my_model_select = model_select
                        my_location_mode = int(m_location_mode)
                        
                        pdf_gen.generate_pdf_report(df, rpt_name, user_name, to_email, my_location_mode, my_model_select, 
                                                    aca_weight, afd_weight, exc_weight, ath_weight, soc_weight)
                        
                        email_client.send_email(rpt_name,to_email,user_name)
                        
                        # Thank You Screen & Close Button
                        bg_exit_frame = tk.Frame(root,bg='#000000',
                                      bd=5)
                        bg_exit_frame.place(relx=0.5,
                                          rely=0.2,
                                          relwidth=0.6,
                                          relheight=0.6,
                                          anchor='n')

                        exit_frame = tk.Frame(bg_exit_frame,bg='#D8DDDD',
                                          bd=5)
                        exit_frame.place(relx=0,
                                          rely=0,
                                          relwidth=0.995,
                                          relheight=0.995,
                                          anchor='nw')
                        
                        ty_label = tk.Label(exit_frame,bg='#D8DDDD',font = ('Arial', 18),anchor = 'n',justify = 'center',wraplength=350,text=f"Thank You For Choosing True Blue Times' College Fit Algorithm!")
                        ty_label.place(relx=0.5,
                                       rely=0,
                                       relheight=0.5,
                                       relwidth=0.995,
                                       anchor='n')
                        
                        exit_button = tk.Button(exit_frame, text="EXIT",font = ('Arial', 18),command=exit_procedure,anchor='n',bg='#E7ECEC')
                        exit_button.place(relx=0.5,rely=0.85,relwidth=0.5,relheight=0.15,anchor='n')
                        
                        return


                    try:
                        for widget in frame_r.winfo_children():
                            widget.destroy()
                            
                        frame_r.destroy()
                        bg_frame_r.destroy()
                    except:
                        pass

                    rpt_name_var = tk.StringVar()
                    to_email_var = tk.StringVar()
                    user_name_var = tk.StringVar()

                    bg_info_frame = tk.Frame(root,bg='#000000',
                                      bd=5)
                    bg_info_frame.place(relx=0.5,
                                      rely=0.2,
                                      relwidth=0.6,
                                      relheight=0.6,
                                      anchor='n')

                    info_frame = tk.Frame(bg_info_frame,bg='#D8DDDD',
                                      bd=5)
                    info_frame.place(relx=0,
                                      rely=0,
                                      relwidth=0.995,
                                      relheight=0.995,
                                      anchor='nw')
                    
                    info_title_label = tk.Label(info_frame,bg='#D8DDDD',font = ('Arial', 24,'bold'),anchor = 'n',justify = 'center',text=f"Enter Info Below")
                    info_title_label.place(relx=0.5,
                                           rely=0.025,
                                           relwidth=0.995,
                                           relheight=0.2,
                                           anchor='n')
                    
                    
                    rpt_name_label = tk.Label(info_frame,bg='#D8DDDD',font = ('Arial', 14),anchor = 'nw',justify = 'right',text=f"Filename:")
                    rpt_name_label.place(relx=0.05,
                                        rely=0.25,
                                        relwidth=0.3,
                                        relheight=0.1,
                                        anchor='nw')

                    rpt_name_entry = tk.Entry(info_frame,
                                              textvariable = rpt_name_var,
                                              font=('Arial',11,'normal'))
                    rpt_name_entry.place(relx=0.35,
                                          rely=0.25,
                                          relwidth=0.65,
                                          relheight=0.1,
                                          anchor='nw')

                    to_email_label = tk.Label(info_frame,bg='#D8DDDD',font = ('Arial', 14),anchor = 'nw',justify = 'right',text=f"Email Address:")
                    to_email_label.place(relx=0.05,
                                         rely=0.45,
                                         relwidth=0.3,
                                         relheight=0.1,
                                         anchor='nw')

                    to_email_entry = tk.Entry(info_frame,
                                              textvariable = to_email_var,
                                              font=('Arial',11,'normal'))
                    to_email_entry.place(relx=0.35,
                                          rely=0.45,
                                          relwidth=0.65,
                                          relheight=0.1,
                                          anchor='nw')
                    
                    user_name_label = tk.Label(info_frame,bg='#D8DDDD',font = ('Arial', 14),anchor = 'nw',justify = 'right',text=f"Enter Name:")
                    user_name_label.place(relx=0.05,
                                          rely=0.65,
                                          relwidth=0.3,
                                          relheight=0.1,
                                          anchor='nw')
                    
                    user_name_entry = tk.Entry(info_frame,
                                              textvariable = user_name_var,
                                              font=('Arial',11,'normal'))
                    user_name_entry.place(relx=0.35,
                                          rely=0.65,
                                          relwidth=0.65,
                                          relheight=0.1,
                                          anchor='nw')
                    
                    # Go Button Here
                    email_button = tk.Button(info_frame, text="Send Email",font = ('Arial', 18),command=email_button_fn,anchor='n',bg='#E7ECEC')
                    email_button.place(relx=0.5,rely=0.85,relwidth=0.3,relheight=0.15,anchor='n')

                    return
                
                # DESTROY STATEMENTS
                try:
                    label_t4.destroy()
                except:
                    pass
                try:
                    go_button_4.place_forget()
                except:
                    pass
                try:
                    radius_label.destroy()
                except:
                    pass
                try:
                    radius_input.destroy()
                except:
                    pass
                try:
                    location_label.destroy()
                except:
                    pass
                try:
                    location_input.destroy()
                except:
                    pass
                try:
                    state_label.destroy()
                except:
                    pass
                try:
                    state_input.destroy()
                except:
                    pass
                
                try:
                    for widget in bg_frame_ad.winfo_children():
                        widget.destroy()

                    bg_frame_ad.destroy()
                except:
                    pass
                
                try:
                    my_n_radius = int(n_radius.get())
                except:
                    my_n_radius = 0
                    
                try:
                    my_location = location.get()
                except:
                    my_location = ''
                    
                try:
                    raw_state_list = state_list_var.get()
                    raw_split = raw_state_list.split(',')
                    my_state_list = []
                    for item in raw_split:
                        my_item = item.strip()
                        my_state_list.append(my_item)
                except:
                    my_state_list = []
                    
                # This fn is going to call main_script & output stuff into r-frame
                df = pd.read_csv('../data/Interim/component_weights.csv')
                try:
                    df = df.drop('Unnamed: 0',axis=1)
                except:
                    pass
                try:
                    aca_weight = int(df['Academic'].iat[0])
                except:
                    aca_weight = 0
                try:
                    ath_weight = int(df['Athletic'].iat[0])
                except:
                    ath_weight = 0
                try:
                    exc_weight = int(df['Exclusivity'].iat[0])
                except:
                    exc_weight = 0
                try:
                    soc_weight = int(df['Social'].iat[0])
                except:
                    soc_weight = 0
                try:
                    afd_weight = int(df['Affordability'].iat[0])
                except:
                    afd_weight = 0
                
                df = model_gen.model_builder(model_select = model_select, 
                                             location_mode = int(m_location_mode),
                                             location = my_location,
                                             n_radius = my_n_radius,
                                             state_list = my_state_list,
                                             aca = aca_weight,
                                             ath = ath_weight,
                                             soc = exc_weight,
                                             exc = soc_weight,
                                             afd = afd_weight)
                
                for idx,row in df.iterrows():
                    raw_website = str(row['Website'])
                    my_website = raw_website.replace('https://','')
                    
                    if 'www.' not in my_website:
                        my_website = 'www.' + my_website
                        
                    
                    slash_found = my_website.find('/')
                    if slash_found != -1:
                        my_website = my_website[:slash_found]
                    
                    
                    df.at[idx,'Website'] = my_website
                
                df.to_csv('../data/Interim/df_to_email.csv')
                
                df_10 = df.head(10)
                c_id_list = df_10['C_ID'].to_list()
                
                df_10 = df_10[['Scaled_Rank','College','City','State','Website']]

                rk_list = df_10['Scaled_Rank'].to_list()
                school_list = df_10['College'].to_list()
                city_list = df_10['City'].to_list()
                state_list = df_10['State'].to_list()
                link_list = df_10['Website'].to_list()
                
                #kill frame_l and bg_frame_l
                frame_l.destroy()
                bg_frame_l.destroy()
                
                # Right Results Box
                bg_frame_r = tk.Frame(root,bg='#000000',
                                      bd=5)
                bg_frame_r.place(relx=0.5,
                                  rely=0.18,
                                  relwidth=0.98,
                                  relheight=0.8,
                                  anchor='n')

                frame_r = tk.Frame(bg_frame_r,         # parent container
                                   bg='#FFFFFF', # bg is background color: can be hex or kw
                                   bd=1)         # bd is 'border' width

                frame_r.place(relx=0.5,
                              rely=0,
                              relwidth=0.995,
                              relheight=0.995,
                              anchor='n')
                
                Title_Label = tk.Label(frame_r,bg='#E7ECEC',font = ('Arial', 21,'bold'),anchor = 'n',justify = 'center',bd=4,text=f"Your 'Best-Fit®' Colleges")
                Title_Label.place(relx=0,rely=0,relwidth=0.65,relheight=0.083)
                
                # Column Headers
                LH1 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'bold'),anchor = 'nw',justify = 'left',bd=4,text=f"Rk")
                LH2 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'bold'),anchor = 'nw',justify = 'left',bd=4,text=f"Logo")
                LH3 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'bold'),anchor = 'nw',justify = 'left',bd=4,text=f"School")
                LH4 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'bold'),anchor = 'nw',justify = 'left',bd=4,text=f"City")
                LH5 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'bold'),anchor = 'nw',justify = 'left',bd=4,text=f"State")
                LH6 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'bold'),anchor = 'nw',justify = 'left',bd=4,text=f"Website")
                
                LH1.place(relx=0.0,rely=0.093,relwidth=0.05,relheight=0.083)
                LH2.place(relx=0.06,rely=0.093,relwidth=0.13,relheight=0.083)
                LH3.place(relx=0.2,rely=0.093,relwidth=0.44,relheight=0.083)
                LH4.place(relx=0.65,rely=0.093,relwidth=0.14,relheight=0.083)
                LH5.place(relx=0.8,rely=0.093,relwidth=0.19,relheight=0.083)
                LH6.place(relx=0.9,rely=0.093,relwidth=0.09,relheight=0.083)
                
                # Top School
                if len(df_10) == 0:
                    na = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 22),anchor = 'nw',justify = 'center',bd=4,text=f"NO DATA AVAILABLE")
                    na.place(relx=0,rely=0.4,relwidth=1.0,relheight=0.4)
                    
                if len(df_10)>=1:
                    L11 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[0]}")

                    try:
                        frame_12 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_12.place(relx=0.06,rely=0.186,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[0]}.png')

                        L12 = tk.Label(frame_12,image=my_image,anchor='nw')
                        L12.image = my_image

                        L12.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L12 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L12.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L12 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L12.place(relx=0.06,rely=0.186,relwidth=0.13,relheight=0.083)
                    
                    L13 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[0]}")
                    L14 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[0]}")
                    L15 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[0]}")
                    L16 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L11.place(relx=0.0,rely=0.186,relwidth=0.05,relheight=0.083)
                    #L12.place(relx=0.06,rely=0.186,relwidth=0.13,relheight=0.083)
                    L13.place(relx=0.2,rely=0.186,relwidth=0.44,relheight=0.083)
                    L14.place(relx=0.65,rely=0.186,relwidth=0.14,relheight=0.083)
                    L15.place(relx=0.8,rely=0.186,relwidth=0.09,relheight=0.083)
                    L16.place(relx=0.9,rely=0.186,relwidth=0.09,relheight=0.083)
                    
                    L16.bind("<Button-1>", lambda e:callback(f"http://{link_list[0]}"))
                    
                if len(df_10)>=2:
                    L21 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[1]}")
                    
                    try:
                        frame_22 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_22.place(relx=0.06,rely=0.279,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[1]}.png')

                        L22 = tk.Label(frame_22,image=my_image,anchor='nw')
                        L22.image = my_image

                        L22.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L22 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L22.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L22 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L22.place(relx=0.06,rely=0.279,relwidth=0.13,relheight=0.083)
                    
                    L23 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[1]}")
                    L24 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[1]}")
                    L25 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[1]}")
                    L26 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L21.place(relx=0.0,rely=0.279,relwidth=0.05,relheight=0.083)
                    #L22.place(relx=0.06,rely=0.279,relwidth=0.13,relheight=0.083)
                    L23.place(relx=0.2,rely=0.279,relwidth=0.44,relheight=0.083)
                    L24.place(relx=0.65,rely=0.279,relwidth=0.14,relheight=0.083)
                    L25.place(relx=0.8,rely=0.279,relwidth=0.09,relheight=0.083)
                    L26.place(relx=0.9,rely=0.279,relwidth=0.09,relheight=0.083)
                    
                    L26.bind("<Button-1>", lambda e:callback(f"http://{link_list[1]}"))
                    
                if len(df_10)>=3:
                    L31 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[2]}")
                    
                    try:
                        frame_32 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_32.place(relx=0.06,rely=0.372,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[2]}.png')

                        L32 = tk.Label(frame_32,image=my_image,anchor='nw')
                        L32.image = my_image

                        L32.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L32 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L32.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L32 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L32.place(relx=0.06,rely=0.372,relwidth=0.13,relheight=0.083)
                    
                    L33 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[2]}")
                    L34 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[2]}")
                    L35 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[2]}")
                    L36 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L31.place(relx=0.0,rely=0.372,relwidth=0.05,relheight=0.083)
                    #L32.place(relx=0.06,rely=0.372,relwidth=0.13,relheight=0.083)
                    L33.place(relx=0.2,rely=0.372,relwidth=0.44,relheight=0.083)
                    L34.place(relx=0.65,rely=0.372,relwidth=0.14,relheight=0.083)
                    L35.place(relx=0.8,rely=0.372,relwidth=0.09,relheight=0.083)
                    L36.place(relx=0.9,rely=0.372,relwidth=0.09,relheight=0.083)
                    
                    L36.bind("<Button-1>", lambda e:callback(f"http://{link_list[2]}"))
                    
                    
                if len(df_10)>=4:
                    L41 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[3]}")
                    try:
                        frame_42 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_42.place(relx=0.06,rely=0.465,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[3]}.png')

                        L42 = tk.Label(frame_42,image=my_image,anchor='nw')
                        L42.image = my_image

                        L42.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L42 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L42.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L42 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L42.place(relx=0.06,rely=0.465,relwidth=0.13,relheight=0.083)
                    L43 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[3]}")
                    L44 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[3]}")
                    L45 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[3]}")
                    L46 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L41.place(relx=0.0,rely=0.465,relwidth=0.05,relheight=0.083)
                    #L42.place(relx=0.06,rely=0.465,relwidth=0.13,relheight=0.083)
                    L43.place(relx=0.2,rely=0.465,relwidth=0.29,relheight=0.083)
                    L44.place(relx=0.65,rely=0.465,relwidth=0.14,relheight=0.083)
                    L45.place(relx=0.8,rely=0.465,relwidth=0.09,relheight=0.083)
                    L46.place(relx=0.9,rely=0.465,relwidth=0.09,relheight=0.083)
                    
                    L46.bind("<Button-1>", lambda e:callback(f"http://{link_list[3]}"))
                    
                if len(df_10)>=5:
                    L51 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[4]}")
                    try:
                        frame_52 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_52.place(relx=0.06,rely=0.558,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[4]}.png')

                        L52 = tk.Label(frame_52,image=my_image,anchor='nw')
                        L52.image = my_image

                        L52.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L52 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L52.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L52 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L52.place(relx=0.06,rely=0.558,relwidth=0.13,relheight=0.083)
                    L53 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[4]}")
                    L54 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[4]}")
                    L55 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[4]}")
                    L56 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L51.place(relx=0.0,rely=0.558,relwidth=0.05,relheight=0.083)
                    #L52.place(relx=0.06,rely=0.558,relwidth=0.13,relheight=0.083)
                    L53.place(relx=0.2,rely=0.558,relwidth=0.44,relheight=0.083)
                    L54.place(relx=0.65,rely=0.558,relwidth=0.14,relheight=0.083)
                    L55.place(relx=0.8,rely=0.558,relwidth=0.09,relheight=0.083)
                    L56.place(relx=0.9,rely=0.558,relwidth=0.09,relheight=0.083)
                    
                    L56.bind("<Button-1>", lambda e:callback(f"http://{link_list[4]}"))
                    
                if len(df_10)>=6:
                    L61 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[5]}")
                    try:
                        frame_62 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_62.place(relx=0.06,rely=0.651,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[5]}.png')

                        L62 = tk.Label(frame_62,image=my_image,anchor='nw')
                        L62.image = my_image

                        L62.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L62 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L62.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L62 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L62.place(relx=0.06,rely=0.651,relwidth=0.13,relheight=0.083)
                    L63 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[5]}")
                    L64 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[5]}")
                    L65 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[5]}")
                    L66 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L61.place(relx=0.0,rely=0.651,relwidth=0.05,relheight=0.083)
                    #L62.place(relx=0.06,rely=0.651,relwidth=0.13,relheight=0.083)
                    L63.place(relx=0.2,rely=0.651,relwidth=0.44,relheight=0.083)
                    L64.place(relx=0.65,rely=0.651,relwidth=0.14,relheight=0.083)
                    L65.place(relx=0.8,rely=0.651,relwidth=0.09,relheight=0.083)
                    L66.place(relx=0.9,rely=0.651,relwidth=0.09,relheight=0.083)
                    
                    L66.bind("<Button-1>", lambda e:callback(f"http://{link_list[5]}"))
                    
                if len(df_10)>=7:
                    L71 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[6]}")
                    try:
                        frame_72 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_72.place(relx=0.06,rely=0.744,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[6]}.png')

                        L72 = tk.Label(frame_72,image=my_image,anchor='nw')
                        L72.image = my_image

                        L72.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L72 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L72.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L72 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L72.place(relx=0.06,rely=0.744,relwidth=0.13,relheight=0.083)
                    L73 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[6]}")
                    L74 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[6]}")
                    L75 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[6]}")
                    L76 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L71.place(relx=0.0,rely=0.744,relwidth=0.05,relheight=0.083)
                    #L72.place(relx=0.06,rely=0.744,relwidth=0.13,relheight=0.083)
                    L73.place(relx=0.2,rely=0.744,relwidth=0.44,relheight=0.083)
                    L74.place(relx=0.65,rely=0.744,relwidth=0.14,relheight=0.083)
                    L75.place(relx=0.8,rely=0.744,relwidth=0.09,relheight=0.083)
                    L76.place(relx=0.9,rely=0.744,relwidth=0.09,relheight=0.083)
                    
                    L76.bind("<Button-1>", lambda e:callback(f"http://{link_list[6]}"))
                    
                if len(df_10)>=8:
                    L81 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[7]}")
                    try:
                        frame_82 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_82.place(relx=0.06,rely=0.837,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[7]}.png')

                        L82 = tk.Label(frame_82,image=my_image,anchor='nw')
                        L82.image = my_image

                        L82.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L82 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L82.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L82 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L82.place(relx=0.06,rely=0.837,relwidth=0.13,relheight=0.083)
                    L83 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[7]}")
                    L84 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[7]}")
                    L85 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[7]}")
                    L86 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L81.place(relx=0.0,rely=0.837,relwidth=0.05,relheight=0.083)
                    #L82.place(relx=0.06,rely=0.837,relwidth=0.13,relheight=0.083)
                    L83.place(relx=0.2,rely=0.837,relwidth=0.44,relheight=0.083)
                    L84.place(relx=0.65,rely=0.837,relwidth=0.14,relheight=0.083)
                    L85.place(relx=0.8,rely=0.837,relwidth=0.09,relheight=0.083)
                    L86.place(relx=0.9,rely=0.837,relwidth=0.09,relheight=0.083)
                    
                    L86.bind("<Button-1>", lambda e:callback(f"http://{link_list[7]}"))
                    
                if len(df_10)>=9:
                    L91 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{rk_list[8]}")
                    try:
                        frame_92 = tk.Frame(frame_r,bg='#FFFFFF')
                        frame_92.place(relx=0.06,rely=0.93,relwidth=0.0525,relheight=0.083)
                        my_image = tk.PhotoImage(file=f'../images/school_logos/{c_id_list[8]}.png')

                        L92 = tk.Label(frame_92,image=my_image,anchor='nw')
                        L92.image = my_image

                        L92.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                    except:
                        try:
                            L92 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L92.place(relx=0.05,rely=0,relwidth=1.0,relheight=1.0)
                        except:
                            L92 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"IMAGE_PH")
                            L92.place(relx=0.06,rely=0.93,relwidth=0.13,relheight=0.083)
                    L93 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{school_list[8]}")
                    L94 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{city_list[8]}")
                    L95 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11),anchor = 'nw',justify = 'left',text=f"{state_list[8]}")
                    L96 = tk.Label(frame_r,bg='#FFFFFF',font = ('Arial', 11,'underline'),anchor = 'n',justify = 'left',text=f"Link",fg="blue", cursor="hand2")
                    
                    L91.place(relx=0.0,rely=0.93,relwidth=0.05,relheight=0.083)
                    #L92.place(relx=0.06,rely=0.93,relwidth=0.13,relheight=0.083)
                    L93.place(relx=0.2,rely=0.93,relwidth=0.44,relheight=0.083)
                    L94.place(relx=0.65,rely=0.93,relwidth=0.14,relheight=0.083)
                    L95.place(relx=0.8,rely=0.93,relwidth=0.09,relheight=0.083)
                    L96.place(relx=0.9,rely=0.93,relwidth=0.09,relheight=0.083)
                    
                    L96.bind("<Button-1>", lambda e:callback(f"http://{link_list[8]}"))
                
                Restart_Button = tk.Button(frame_r, text="Exit",font = ('Arial', 18),command=exit_procedure,anchor='nw',bg='#E7ECEC')
                Restart_Button.place(relx=0.65,rely=0,relwidth=0.15,relheight=0.083)
                
                Email_Results_Button = tk.Button(frame_r, text="Email My Results",font = ('Arial', 14),command=email_procedure,anchor='nw',bg='#E7ECEC')
                Email_Results_Button.place(relx=0.8,rely=0,relwidth=0.2,relheight=0.083)
                
                return
            
            label_t3.destroy()
            r4.destroy()
            r5.destroy()
            r6.destroy()
            r7.destroy()
            
            go_button_3.place_forget()
            
            m_location_mode = int(location_mode.get())
            
            if m_location_mode == 1:
                b4_fn()
            else:
                label_t4 = tk.Label(frame_l,
                                    bg='#DAD8D7',
                                    font = ('Arial', 18),
                                    anchor = 'n',
                                    justify = 'center',
                                    bd=4,
                                    wraplength=350,
                                    text="Please Enter The Requested Location Data Below:")

                label_t4.place(relx=0,
                               rely=0,
                               relwidth=1.0,
                               relheight=0.38)
                
                if m_location_mode == 2:
                    n_radius = tk.StringVar()
                    location = tk.StringVar()
                    
                    #n-mile radius
                    radius_label = tk.Label(frame_l,
                                            bg='#FFFFFF',
                                            font = ('Arial', 10),
                                            anchor = 'nw',
                                            justify = 'left',
                                            bd=4,
                                            wraplength=350,
                                            text="How Many Miles Is Your Radius?")
                    radius_label.place(relx=0,
                                       rely=0.4,
                                       relwidth=0.6,
                                       relheight=0.2)
                    
                    radius_input = tk.Entry(frame_l,
                                            textvariable = n_radius,
                                            font=('Arial',10,'normal'))
                    radius_input.place(relx=0.6,
                                       rely=0.47,
                                       relwidth=0.4,
                                       relheight=0.1)
                    
                    # location city, state
                    location_label = tk.Label(frame_l,
                                              bg='#FFFFFF',
                                              font = ('Arial', 10),
                                              anchor = 'nw',
                                              justify = 'left',
                                              bd=4,
                                              wraplength=350,
                                              text="Enter Your Location: City, State")
                    
                    location_label.place(relx=0,
                                         rely=0.6,
                                         relwidth=0.6,
                                         relheight=0.2)
                    
                    location_input = tk.Entry(frame_l,
                                            textvariable = location,
                                            font=('Arial',10,'normal'))
                    location_input.place(relx=0.6,
                                         rely=0.67,
                                         relwidth=0.4,
                                         relheight=0.1)
                    
                else:
                    location = tk.StringVar()
                    
                    # location city, state
                    location_label = tk.Label(frame_l,
                                              bg='#FFFFFF',
                                              font = ('Arial', 10),
                                              anchor = 'nw',
                                              justify = 'left',
                                              bd=4,
                                              wraplength=350,
                                              text="Enter Your Location: City, State")
                    
                    location_label.place(relx=0,
                                         rely=0.4,
                                         relwidth=0.6,
                                         relheight=0.2)
                    
                    location_input = tk.Entry(frame_l,
                                            textvariable = location,
                                            font=('Arial',10,'normal'))
                    location_input.place(relx=0.6,
                                         rely=0.47,
                                         relwidth=0.4,
                                         relheight=0.1)
                    
                    if m_location_mode == 4:
                        # State Selection Input
                        state_list_var = tk.StringVar()
                        
                        state_label = tk.Label(frame_l,
                                              bg='#FFFFFF',
                                              font = ('Arial', 10),
                                              anchor = 'nw',
                                              justify = 'left',
                                              bd=4,
                                              wraplength=200,
                                              text="Enter A List of State Abbreviations Separated By Commas")
                        state_label.place(relx=0,
                                          rely=0.7,
                                          relwidth=0.5,
                                          relheight=0.15)
                        
                        state_input = tk.Entry(frame_l,
                                               textvariable = state_list_var,
                                               font=('Arial',10,'normal'))
                        state_input.place(relx=0.5,
                                          rely=0.7,
                                          relwidth=0.5,
                                          relheight=0.1)
                        
                
                go_button_4 = tk.Button(frame_l, 
                            text="Run!",
                            font = ('Arial', 18),
                            command=b4_fn,
                            anchor='n')

                go_button_4.place(relx=0.325,
                                rely=0.9,
                                relwidth=0.35,
                                relheight=0.1)
                
            return
        
        # FUNCTIONALITY
        model_select = model_type.get()
        
        # DESTROY STATEMENTS
        label_t2.destroy()
        r1.destroy()
        r2.destroy()
        r3.destroy()
        
        go_button_2.place_forget()
        
        # NEW ELEMENTS
        label_t3 = tk.Label(frame_l,
                        bg='#DAD8D7',
                        font = ('Arial', 18),
                        anchor = 'n',
                        justify = 'center',
                        bd=4,
                        wraplength=350,
                        text="Please Let The Application Know How You Want It To Consider Location As a Factor In It's Recommendations")

        label_t3.place(relx=0,
                       rely=0,
                       relwidth=1.0,
                       relheight=0.38)
        
        
        location_mode = tk.StringVar()
        location_mode.set('1')
        r4 = tk.Radiobutton(frame_l, 
                        text='Ignore Location Data',
                        font = ('Arial', 10),
                        value='1',
                        justify='left',
                        variable=location_mode)
        
        r4.place(relx=0,
                 rely=0.39,
                 relwidth=1.0,
                 relheight=0.1)
        
        # No Location
        r5 = tk.Radiobutton(frame_l, 
                        text='Only Consider Schools Within an n-mile Radius Of Me',
                        font = ('Arial', 10),
                        value='2', 
                        justify='left',
                        variable=location_mode)
        r5.place(relx=0,
                 rely=0.50,
                 relwidth=1.0,
                 relheight=0.1)
        
        # N-Mile Radius -> sub EntryBox
        r6 = tk.Radiobutton(frame_l, 
                        text="Scale Ranking Based On It's Distance From Me",
                        font = ('Arial', 10),
                        value='3',
                        justify='left',
                        variable=location_mode)
        r6.place(relx=0,
                 rely=0.61,
                 relwidth=1.0,
                 relheight=0.1)
        
        # Sigmoid Scaling -> sub EntryBox
        r7 = tk.Radiobutton(frame_l, 
                            text='Only Consider Certain States',
                            font = ('Arial', 10),
                            value='4', 
                            justify='left',
                            variable=location_mode)# Allowable State List - sub EntryBox
        r7.place(relx=0,
                 rely=0.72,
                 relwidth=1.0,
                 relheight=0.1)
        
        
        go_button_3 = tk.Button(frame_l, 
                            text="Go!",
                            font = ('Arial', 18),
                            command=b3_fn,
                            anchor='n')

        go_button_3.place(relx=0.325,
                        rely=0.9,
                        relwidth=0.35,
                        relheight=0.1)
        
        return
    
    # FUNCTIONALITY 
    aca = int(w1.get())
    ath = int(w2.get())
    exc = int(w3.get())
    soc = int(w4.get())
    afd = int(w5.get())

    
    d = {'Academic': aca, 'Athletic': ath, 'Exclusivity':exc, 'Social':soc, 'Affordability':afd}
    df = pd.DataFrame(data=d,index={0})
    
    df.to_csv('../data/Interim/component_weights.csv')
    
    # DESTROY STATEMENTS
    w1.destroy()
    w2.destroy()
    w3.destroy()
    w4.destroy()
    w5.destroy()
    
    label_1.destroy()
    label_2.destroy()
    label_3.destroy()
    label_4.destroy()
    label_5.destroy()
    
    label_t.destroy()
    
    go_button.place_forget()
    
    # NEW ELEMENTS
    label_t2 = tk.Label(frame_l,
                        bg='#DAD8D7',
                        font = ('Arial', 18),
                        anchor = 'n',
                        justify = 'center',
                        bd=4,
                        wraplength=350,
                        text="Please Select How Complex Of an Algorithm You Want The App To Create")

    label_t2.place(relx=0,
                   rely=0,
                   relwidth=1.0,
                   relheight=0.38)
    
    model_type = tk.StringVar()
    model_type.set('LASSO')
    r1 = tk.Radiobutton(frame_l, 
                        text='Low Complexity - Super Fast (LASSO Regressor)',
                        font = ('Arial', 10),
                        value='LASSO', 
                        variable=model_type)
    r1.place(relx=0,
             rely=0.4,
             relwidth=1.0,
             relheight=0.15)
    
    r2 = tk.Radiobutton(frame_l, 
                        text='Medium Complexity - (Random Forest Regressor)',
                        font = ('Arial', 10),
                        value='RF', 
                        variable=model_type)
    r2.place(relx=0,
             rely=0.56,
             relwidth=1.0,
             relheight=0.15)
    
    r3 = tk.Radiobutton(frame_l, 
                        text='High Complexity - (AdaBoost Regressor)',
                        font = ('Arial', 10),
                        value='ADA', 
                        variable=model_type)
    r3.place(relx=0,
             rely=0.72,
             relwidth=1.0,
             relheight=0.15)
    
    go_button_2 = tk.Button(frame_l, 
                            text="Next",
                            font = ('Arial', 18),
                            command=b2_fn,
                            anchor='n')

    go_button_2.place(relx=0.325,
                    rely=0.9,
                    relwidth=0.35,
                    relheight=0.1)
    
    return

# %%
#Root Contains All Items (Including Sub-Containers)
HEIGHT = 600
WIDTH = 800
root = tk.Tk()
root.attributes("-topmost", True)
root.title('College Ranking System | True Blue Times')
root.iconbitmap('../images/app_logo.ico')



#Canvas 
canvas = tk.Canvas(root,
                   height=HEIGHT,
                   width=WIDTH)
canvas.pack()

# Background
background_image = tk.PhotoImage(file='../images/background.png')
background_label = tk.Label(root, image=background_image)
background_label.place(x=0,
                       y=0,
                       relwidth = 1,
                       relheight = 1)

#######################################################################
# Title Bar
frame_t = tk.Frame(root,         # parent container
                 bg='#000000', # bg is background color: can be hex or kw
                 bd=5)         # bd is 'border' width

frame_t.place(relx=0.5,
            rely=0.0125,
            relwidth=0.95,
            relheight=0.15,
            anchor='n')

sub_frame_1 = tk.Frame(frame_t,
                       bg='#FFFFFF')

sub_frame_1.place(relx=0,
                  rely=0.5,
                  relwidth=0.15,
                  relheight=1,
                  anchor='w')

app_image = tk.PhotoImage(file='../images/MTSU.png') # 110px x 110px

app_image_label = tk.Label(sub_frame_1, image=app_image)

app_image_label.place(x=0,
                      y=0,
                      relwidth = 1,
                      relheight = 1,
                      anchor='nw')


sub_frame_2 = tk.Frame(frame_t,
                       bg='#FFFFFF',
                       bd=5)

sub_frame_2.place(relx=0.58,
                  rely=0,
                  relwidth=0.84,
                  relheight=1,
                  anchor='n')

label = tk.Label(sub_frame_2,
                 bg='#FFFFFF',
                 font = ('Arial', 22),
                 anchor = 'nw',
                 justify = 'left',
                 bd = 4,
                 text = "TBT Dynamic College 'Fit' Finder")

label.place(relwidth = 1,
            relheight = 0.59)

label = tk.Label(sub_frame_2,
                 bg='#FFFFFF',
                 font = ('Arial', 11),
                 anchor = 'w',
                 justify = 'left',
                 bd = 4,
                 text = "Developed By: Robert Mepham | © 2022. All Rights Reserved.")

label.place(relx=0,
            rely=0.61,
            relwidth = 1,
            relheight = 0.39)

#######################################################################
# Left Action Box
bg_frame_l = tk.Frame(root,bg='#000000',
                      bd=5)
bg_frame_l.place(relx=0.25,
                  rely=0.18,
                  relwidth=0.45,
                  relheight=0.8,
                  anchor='n')

frame_l = tk.Frame(bg_frame_l,         # parent container
                   bg='#FFFFFF', # bg is background color: can be hex or kw
                   bd=5)         # bd is 'border' width

frame_l.place(relx=0.5,
              rely=0,
              relwidth=0.995,
              relheight=0.995,
              anchor='n')

label_1 = tk.Label(frame_l,
                 bg='#FFFFFF',
                 font = ('Arial', 18),
                 anchor = 'e',
                 justify = 'right',
                 bd =4,
                 text = "Academics")
label_1.place(relx=0.005,
              rely=0.4,
              relwidth =0.4,
              relheight = 0.09)
w1 = tk.Scale(frame_l, from_=0, to=100,orient=tk.HORIZONTAL)
w1.set(50)
w1.place(relx=0.42,
         rely=0.4,
         relwidth=0.58)

label_2 = tk.Label(frame_l,
                 bg='#FFFFFF',
                 font = ('Arial', 18),
                 anchor = 'e',
                 justify = 'right',
                 bd =4,
                 text = "Athletics")
label_2.place(relx=0.005,
              rely=0.5,
              relwidth =0.4,
              relheight = 0.09)
w2 = tk.Scale(frame_l, from_=0, to=100,orient=tk.HORIZONTAL)
w2.set(50)
w2.place(relx=0.42,
         rely=0.5,
         relwidth=0.58)

label_3 = tk.Label(frame_l,
                 bg='#FFFFFF',
                 font = ('Arial', 18),
                 anchor = 'e',
                 justify = 'right',
                 bd =4,
                 text = "Exclusivity")
label_3.place(relx=0.005,
              rely=0.6,
              relwidth =0.4,
              relheight = 0.09)
w3 = tk.Scale(frame_l, from_=0, to=100,orient=tk.HORIZONTAL)
w3.set(50)
w3.place(relx=0.42,
         rely=0.6,
         relwidth=0.58)

label_4 = tk.Label(frame_l,
                 bg='#FFFFFF',
                 font = ('Arial', 18),
                 anchor = 'e',
                 justify = 'right',
                 bd =4,
                 text = "Social Life")
label_4.place(relx=0.005,
              rely=0.7,
              relwidth =0.4,
              relheight = 0.09)
w4 = tk.Scale(frame_l, from_=0, to=100,orient=tk.HORIZONTAL)
w4.set(50)
w4.place(relx=0.42,
         rely=0.7,
         relwidth=0.58)

label_5 = tk.Label(frame_l,
                 bg='#FFFFFF',
                 font = ('Arial', 18),
                 anchor = 'e',
                 justify = 'right',
                 bd =4,
                 text = "Affordability")
label_5.place(relx=0.005,
              rely=0.8,
              relwidth =0.4,
              relheight = 0.09)
w5 = tk.Scale(frame_l, from_=0, to=100,orient=tk.HORIZONTAL)
w5.set(50)
w5.place(relx=0.42,
         rely=0.8,
         relwidth=0.58)

label_t = tk.Label(frame_l,
                   bg='#DAD8D7',
                   font = ('Arial', 18),
                   anchor = 'n',
                   justify = 'center',
                   bd=4,
                   wraplength=350,
                   text="Please Select What The Algorithm Should Value When Deciding Your Ideal College Fit")

label_t.place(relx=0,
              rely=0,
              relwidth=1.0,
              relheight=0.38)

go_button = tk.Button(frame_l, 
                      text="Next",
                      font = ('Arial', 18),
                      command=fn_1,
                      anchor='n')

go_button.place(relx=0.325,
                rely=0.9,
                relwidth=0.35,
                relheight=0.1)

#################################################################################
# ADVERTISEMENT PANE (where frame_r was on launch)
bg_frame_ad = tk.Frame(root,bg='#000000',
                      bd=5)
bg_frame_ad.place(relx=0.75,
                  rely=0.18,
                  relwidth=0.45,
                  relheight=0.8,
                  anchor='n')

frame_ad = tk.Frame(bg_frame_ad,   # parent container
                   bg='#FFFFFF', # bg is background color: can be hex or kw
                   bd=5)         # bd is 'border' width

frame_ad.place(relx=0.5,
              rely=0,
              relwidth=0.995,
              relheight=0.995,
              anchor='n')
# Headshot
my_image = tk.PhotoImage(file=f'../images/ad_pane/rob_headshot.png')
headshot_label = tk.Label(frame_ad,image=my_image,anchor='n')
headshot_label.image = my_image
headshot_label.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.5)

# Name
name_box = tk.Frame(frame_ad,
                     bg = '#D8DDDD',
                     bd = 5)
name_box.place(relx=0.5,
                rely=0.0,
                relwidth = 0.995,
                relheight=0.1,
                anchor='n')

name_label = tk.Label(name_box,bg='#FFFFFF',font = ('Arial', 16,'bold'),anchor = 'n',justify = 'center',text=f"Developed By: Robert Mepham")
name_label.place(relx=0.5,
                rely=0,
                relwidth = 0.995,
                relheight=1.0,
                anchor='n')

# Links: LinkedIn, GitHub, Twitter, Instagram
links_box = tk.Frame(frame_ad,
                     bg = '#D8DDDD',
                     bd = 5)
links_box.place(relx=0.5,
                rely=0.6,
                relwidth = 0.995,
                relheight=0.4,
                anchor='n')

my_image = tk.PhotoImage(file=f'../images/ad_pane/TWTR.png')
twtr_logo = tk.Label(links_box,image=my_image,anchor='n')
twtr_logo.image = my_image
twtr_logo.place(relx=0.05,
                rely=0.05,
                relwidth = 0.12,
                relheight=0.22,
                anchor='n')

my_image = tk.PhotoImage(file=f'../images/ad_pane/INST.png')
insta_logo = tk.Label(links_box,image=my_image,anchor='n')
insta_logo.image = my_image
insta_logo.place(relx=0.05,
                rely=0.29,
                relwidth = 0.12,
                relheight=0.22,
                anchor='n')

my_image = tk.PhotoImage(file=f'../images/ad_pane/LKIN.png')
lkdn_logo = tk.Label(links_box,image=my_image,anchor='n')
lkdn_logo.image = my_image
lkdn_logo.place(relx=0.05,
                rely=0.53,
                relwidth = 0.12,
                relheight=0.22,
                anchor='n')

my_image = tk.PhotoImage(file=f'../images/ad_pane/GHUB.png')
github_logo = tk.Label(links_box,image=my_image,anchor='n')
github_logo.image = my_image
github_logo.place(relx=0.05,
                rely=0.77,
                relwidth = 0.12,
                relheight=0.22,
                anchor='n')

twtr_link = tk.Label(links_box,bg='#D8DDDD',font = ('Arial', 14,'underline'),anchor = 'nw',justify = 'left',text=f"@hoop_power",fg="blue", cursor="hand2")
twtr_link.place(relx=0.2,
                rely=0.05,
                relwidth = 0.78,
                relheight=0.22,
                anchor='nw')
twtr_link.bind("<Button-1>", lambda e:callback(f"http://twitter.com/hoop_power"))

insta_link = tk.Label(links_box,bg='#D8DDDD',font = ('Arial', 14,'underline'),anchor = 'nw',justify = 'left',text=f"@hooppoweranalytics",fg="blue", cursor="hand2")
insta_link.place(relx=0.2,
                rely=0.29,
                relwidth = 0.78,
                relheight=0.22,
                anchor='nw')
insta_link.bind("<Button-1>", lambda e:callback(f"http://www.instagram.com/hooppoweranalytics"))

ghub_link = tk.Label(links_box,bg='#D8DDDD',font = ('Arial', 14,'underline'),anchor = 'nw',justify = 'left',text=f"@robmepham",fg="blue", cursor="hand2")
ghub_link.place(relx=0.2,
                rely=0.77,
                relwidth = 0.78,
                relheight=0.22,
                anchor='nw')
ghub_link.bind("<Button-1>", lambda e:callback(f"http://github.com/RobMepham"))

lkdn_link = tk.Label(links_box,bg='#D8DDDD',font = ('Arial', 14,'underline'),anchor = 'nw',justify = 'left',text=f"Robert Mepham",fg="blue", cursor="hand2")
lkdn_link.place(relx=0.2,
                rely=0.53,
                relwidth = 0.78,
                relheight=0.22,
                anchor='nw')
lkdn_link.bind("<Button-1>", lambda e:callback(f"http://www.linkedin.com/in/robert-mepham/"))

root.mainloop()
