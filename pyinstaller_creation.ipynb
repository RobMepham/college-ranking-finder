# %%
# !pip install pyinstaller

# %%
# !pyinstaller --onefile -w main_script.py
# Out:
# 1193 INFO: PyInstaller: 5.3
# 1193 INFO: Python: 3.9.7 (conda)
# 1201 INFO: Platform: Windows-10-10.0.22000-SP0
# 1201 INFO: wrote C:\Users\mepha\Class Work\DATA 4950\src\main_script.spec
# 1203 INFO: UPX is not available.
# 1208 INFO: Extending PYTHONPATH with paths
# ['C:\\Users\\mepha\\Class Work\\DATA 4950\\src']
# 2219 INFO: checking Analysis
# 2219 INFO: Building Analysis because Analysis-00.toc is non existent
# 2219 INFO: Initializing module dependency graph...
# 2226 INFO: Caching module graph hooks...
# 2237 INFO: Analyzing base_library.zip ...
# 11167 INFO: Processing pre-find module path hook distutils from 'C:\\Users\\mepha\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 11168 INFO: distutils: retargeting to non-venv dir 'C:\\Users\\mepha\\anaconda3\\lib'
# 14630 INFO: Caching module dependency graph...
# 14783 INFO: running Analysis Analysis-00.toc
# ...
